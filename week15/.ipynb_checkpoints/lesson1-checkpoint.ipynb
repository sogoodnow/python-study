# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame({
    'stu_no':['s1','s2','s3','s4','s5','s6','s7','s1'],
    'score':np.random.randint(50,100,size=8),
})

# %%
df1
# Out:
#   stu_no  score
# 0     s1     66
# 1     s2     78
# 2     s3     57
# 3     s4     90
# 4     s5     52
# 5     s6     87
# 6     s7     77
# 7     s1     56

# %%
import pymysql

db=pymysql.connect(host='127.0.0.1',port=3306,user='root',password='root',database='test',charset='utf8')

# %%
sql = "select * from douban"

# %%
data = pd.read_sql(sql,db)
db.close()

# %%
data
# Out:
#       id      bookname                     author    publish  \
# 0      1         透视的艺术                       None  上海人民美术出版社
# 1      2     产品经理的第一本书                     林达·哥乔斯  中国财政经济出版社
# 2      3        中国小说史略                         鲁迅    上海古籍出版社
# 3      4            创意  [美]\n            詹姆斯·韦伯·扬    中国海关出版社
# 4      5      约翰·克利斯朵夫     [法]\n            罗曼·罗兰    人民文学出版社
# 5      6            伤逝                         鲁迅    中国青年出版社
# 6      7       业余无线电通信                       None    人民邮电出版社
# 7      8         炒股的智慧                        陈江挺    经济科学出版社
# 8      9         素描的诀窍    [美]\n            伯特·多德森  上海人民美术出版社
# 9     10       中国古代建筑史                        刘敦桢  中国建筑工业出版社
# 10    11       中国古代建筑史                        刘敦桢  中国建筑工业出版社
# 11    12  古龙作品全集（全53卷）                          无    太白文艺出版社
# 12    13       STL源码剖析                         侯捷  华中科技大学出版社
# 13    14            瑜伽                          无       人民体育
# ...

# %%
data.describe()
# Out:
#                id
# count  680.000000
# mean   340.500000
# std    196.443376
# min      1.000000
# 25%    170.750000
# 50%    340.500000
# 75%    510.250000
# max    680.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 680 entries, 0 to 679
# Data columns (total 17 columns):
# id             680 non-null int64
# bookname       680 non-null object
# author         680 non-null object
# publish        680 non-null object
# originame      680 non-null object
# translater     680 non-null object
# ptime          680 non-null object
# pages          680 non-null object
# price          680 non-null object
# zhuangzheng    680 non-null object
# books          680 non-null object
# isbn           680 non-null object
# starts         680 non-null object
# commentcnt     680 non-null object
# weburl         610 non-null object
# bookintro      610 non-null object
# authorintro    610 non-null object
# dtypes: int64(1), object(16)
# memory usage: 90.4+ KB

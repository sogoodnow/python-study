# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 子图

# %%
plt.subplot(2,1,1)
plt.subplot(2,1,2)
plt.show()

# %%
plt.subplot(1,2,1)
plt.subplot(1,2,2)
plt.show()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,1,2)
plt.show()

# %%
plt.subplot(2,2,1)
x=np.random.random(10)
y=np.random.random(10)
plt.scatter(x,y)
plt.subplot(2,2,2)
plt.title('test')
x=np.arange(7)
y=x**2
plt.plot(x,y)
plt.subplot(2,1,2)
plt.show()

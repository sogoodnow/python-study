# %%
import numpy as np

# %%
x= np.array([[1.2, 1.5, 1.8],
[1.3, 1.4, 1.9],
[1.1, 1.6, 1.7]])
y = np.array([5, 10, 9]).T

# %%
x
# Out:
# array([[1.2, 1.5, 1.8],
#        [1.3, 1.4, 1.9],
#        [1.1, 1.6, 1.7]])

# %%
y
# Out:
# array([ 5, 10,  9])

# %%
z=x*y
z
# Out:
# array([[ 6. , 15. , 16.2],
#        [ 6.5, 14. , 17.1],
#        [ 5.5, 16. , 15.3]])

# %%
# %%timeit
z.sum(axis=1)
# Out:
# 1.84 µs ± 37.6 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
z.sum(axis=1)
# Out:
# array([37.2, 37.6, 36.8])

# %%
x[[0,1]]
# Out:
# array([[1.2, 1.5, 1.8],
#        [1.3, 1.4, 1.9]])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3, 3)

# %%
x[(1,2)]
# Out:
# 1.9

# %%
for i in range(3):
    print(x[i]*y)
# Out:
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]

# %%
# %%timeit
for i in range(3):
    print(x[i]*y)
# Out:
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# [ 6.5 14.  17.1]
# [ 5.5 16.  15.3]
# [ 6.  15.  16.2]
# ...
